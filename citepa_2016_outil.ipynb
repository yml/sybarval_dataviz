# %% [markdown]
# # Citepa 2016
#
#
# ##Inventaires spatialisés
#
# ### Format
#
# Ce format de rapportage consiste à spatialiser (c’est-à-dire cartographier dans un cadastre, sur une carte de communes, etc.) des émissions déjà estimées dans l’inventaire. Il s’agit alors d’une autre représentation des données d’émissions, où les émissions sont replacées à leur lieu d’origine.
#
# Nous réalisons aussi des projets de spatialisation d’émissions pour des territoires (pays, régions…): découvrez notre offre de prestations sur la spatialisation.
#
# ### Contexte
#
# #### Spatialisation des émissions de polluants
#
#
# Dans le cadre de la CEE-NU, les émissions de polluants doivent être régulièrement spatialisées au sein de la Grille Emep.
# Au niveau des régions, les AASQA peuvent réaliser des cadastres d’émission: consulter leurs sites respectifs.
#
# ##### Spatialisation des émissions de gaz à effet de serre
#
#
# Dans le cadre de la CCNUCC, aucune spatialisation des émissions de GES n’est requise.
# Dans le cadre du décret n°2016-849 du 28 juin 2016, complété par l’arrêté du 4 août 2016, les intercommunalités à fiscalité propre de plus de 20 000 habitants doivent inclure dans leur Plan Climat Air Energie Territorial (PCAET) un diagnostic relatif à l’estimation des émissions territoriales de gaz à effet de serre et de polluants atmosphériques. Le Citepa a réalisé la spatialisation, par commune, des émissions de GES de 2016 et 2018 afin de fournir à ces intercommunalités, si besoin, une estimation par défaut.
# Le Citepa a aussi participé à la réalisation et à la mise à jour de l’Inventaire National Spatialisé (INS).
#
# ### Substances couvertes
#
# Gaz à effet de serre : CO2, CH4, N2O, HFC, PFC, SF6, NF3, total en CO2e.
#
# Polluants : le SO2, les NOX, le NH3, les COVNM, le CO, les métaux lourds (As, Cd, Cr, Cu, Hg, Ni, Pb, Se, Zn), les poussières totales en suspension (TSP), les particules fines (PM10 et PM2,5) , le black carbon (carbone suie, BC) et certains composés organiques persistants (POP) tels que les dioxines et les furannes (PCDD/F), les hydrocarbures aromatiques polycycliques (HAP) sous forme spéciée (BaP, BbF, BkF et IndPy), les polychlorobiphényles (PCB) et l’hexachlorobenzène (HCB).
#
#
# * source: https://www.citepa.org/fr/inventaire-spatialise/
# * data: https://www.citepa.org/wp-content/uploads/SYNTHESE_resultats_emissions_2016_IGT_d.xlsx

# %%
import pandas as pd

FILE = "_data_cache/SYNTHESE_resultats_emissions_2016_IGT_d.xlsx"

df_prg = pd.read_excel(FILE, sheet_name="PRG")
df_population = pd.read_excel(FILE, sheet_name="Population")
df_communes = pd.read_excel(FILE, sheet_name="Communes")

# %%
df_prg.head()
# Out:
#   CODE POL CODE_COM_2020       EPCI      Energie  Industrie_hors_energie  \
# 0      PRG         01001  200069193     0.000000                2.050853
# 1      PRG         01002  240100883     0.000000                0.000000
# 2      PRG         01004  240100883  1235.413217             5737.995199
# 3      PRG         01005  200042497    89.944431              512.394565
# 4      PRG         01006  200040350     0.000000                0.000000
#
#     Residentiel     Tertiaire      Dechets       Routier  Autres_Transports  \
# 0    350.683419    204.390115    24.414205    807.369162           0.000000
# 1    116.960942     60.764951    21.831573    344.271792           0.000000
# 2  15110.947343  10577.155783  5924.758242  16486.929424         179.154574
# 3    675.638420    624.233416    53.189227   1799.360239           0.000000
# 4     49.902194     27.506768     7.895160    407.714013           0.000000
#
#    Autres_Transports_international  Agriculture  Unnamed: 12  Unnamed: 13   0  \
# 0                              0.0  3857.574837         True          NaN NaN
# 1                              0.0   631.902243         True          NaN NaN
# 2                              0.0   378.117516         True          NaN NaN
# 3                              0.0  2171.254243         True          NaN NaN
# 4                              0.0   355.614930         True          NaN NaN
#
#    True
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
df_communes.head()
# Out:
#                      NOM  NEW_REG CODE_COM_2020           NOM_COM_2020  \
# 0  ABERGEMENT CLEMENCIAT       84         01001  ABERGEMENT CLEMENCIAT
# 1    ABERGEMENT DE VAREY       84         01002    ABERGEMENT DE VAREY
# 2      AMBERIEU EN BUGEY       84         01004      AMBERIEU EN BUGEY
# 3    AMBERIEUX EN DOMBES       84         01005    AMBERIEUX EN DOMBES
# 4                AMBLEON       84         01006                AMBLEON
#
#                    Nom EPCI       EPCI  Nom en double
# 0           CC de la Dombes  200069193              1
# 1  CC de la Plaine de l'Ain  240100883              1
# 2  CC de la Plaine de l'Ain  240100883              1
# 3    CC Dombes Saône Vallée  200042497              1
# 4              CC Bugey Sud  200040350              1

# %%
df_population.head()
# Out:
#   CODE_COM_2020  CODE_EPCI  Population municipale 2016  Ratio PRG/hab  \
# 0         01001  200069193                         767       6.840264
# 1         01002  240100883                         243       4.838401
# 2         01004  240100883                       14081       3.950747
# 3         01005  200042497                        1671       3.546388
# 4         01006  200040350                         110       7.714846
#
#   Unnamed: 4             Unnamed: 5  Unnamed: 6  \
# 0      01001  ABERGEMENT CLEMENCIAT         NaN
# 1      01002    ABERGEMENT DE VAREY         NaN
# 2      01004      AMBERIEU EN BUGEY         NaN
# 3      01005    AMBERIEUX EN DOMBES         NaN
# 4      01006                AMBLEON         NaN
#
#    Source : Insee, Recensement de la population 2016
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_prg.set_index("CODE_COM_2020")
# Out:
#               CODE POL       EPCI      Energie  Industrie_hors_energie  \
# CODE_COM_2020
# 01001              PRG  200069193     0.000000                2.050853
# 01002              PRG  240100883     0.000000                0.000000
# 01004              PRG  240100883  1235.413217             5737.995199
# 01005              PRG  200042497    89.944431              512.394565
# 01006              PRG  200040350     0.000000                0.000000
# ...                ...        ...          ...                     ...
# 95678              PRG  249500455     0.000000                0.000000
# 95680              PRG  200055655   539.666587             2642.046688
# 95682              PRG  200073013     0.000000                0.000000
# 95690              PRG  249500513     7.936273               35.772549
# 99999              PRG        NaN     0.000000                0.000000
#
#                 Residentiel     Tertiaire      Dechets       Routier  \
# CODE_COM_2020
# 01001            350.683419    204.390115    24.414205    807.369162
# 01002            116.960942     60.764951    21.831573    344.271792
# 01004          15110.947343  10577.155783  5924.758242  16486.929424
# 01005            675.638420    624.233416    53.189227   1799.360239
# 01006             49.902194     27.506768     7.895160    407.714013
# ...                     ...           ...          ...           ...
# 95678           1176.877167    198.081312    27.469960  18054.070687
# 95680          24012.638587  18251.387082   386.043036  12686.681787
# 95682             78.982475     43.325405    16.809469   4875.450927
# 95690            150.244732     77.500288    17.986268    509.751025
# 99999              0.000000      0.000000     0.000000      0.000000
#
#                Autres_Transports  Autres_Transports_international  \
# CODE_COM_2020
# 01001                   0.000000                              0.0
# 01002                   0.000000                              0.0
# 01004                 179.154574                              0.0
# 01005                   0.000000                              0.0
# 01006                   0.000000                              0.0
# ...                          ...                              ...
# 95678                   0.000000                              0.0
# 95680                   0.000000                              0.0
# 95682                   0.000000                              0.0
# 95690                   0.000000                              0.0
# 99999                   0.000000                              0.0
#
#                Agriculture  Unnamed: 12  Unnamed: 13   0  True
# CODE_COM_2020
# 01001          3857.574837         True          NaN NaN   NaN
# 01002           631.902243         True          NaN NaN   NaN
# 01004           378.117516         True          NaN NaN   NaN
# 01005          2171.254243         True          NaN NaN   NaN
# 01006           355.614930         True          NaN NaN   NaN
# ...                    ...          ...          ...  ..   ...
# 95678           686.418235         True          NaN NaN   NaN
# 95680            34.568080         True          NaN NaN   NaN
# 95682           387.169083         True          NaN NaN   NaN
# 95690          1376.379160         True          NaN NaN   NaN
# 99999             0.000000         True          NaN NaN   NaN
#
# [34840 rows x 15 columns]

# %%
df = df_communes.set_index("CODE_COM_2020",drop=False).join(df_prg.set_index("CODE_COM_2020").drop("EPCI", axis=1)).join(df_population.set_index("CODE_COM_2020"))

# %%
df.head()
# Out:
#                                  NOM  NEW_REG CODE_COM_2020  \
# CODE_COM_2020
# 01001          ABERGEMENT CLEMENCIAT       84         01001
# 01002            ABERGEMENT DE VAREY       84         01002
# 01004              AMBERIEU EN BUGEY       84         01004
# 01005            AMBERIEUX EN DOMBES       84         01005
# 01006                        AMBLEON       84         01006
#
#                         NOM_COM_2020                  Nom EPCI       EPCI  \
# CODE_COM_2020
# 01001          ABERGEMENT CLEMENCIAT           CC de la Dombes  200069193
# 01002            ABERGEMENT DE VAREY  CC de la Plaine de l'Ain  240100883
# 01004              AMBERIEU EN BUGEY  CC de la Plaine de l'Ain  240100883
# 01005            AMBERIEUX EN DOMBES    CC Dombes Saône Vallée  200042497
# 01006                        AMBLEON              CC Bugey Sud  200040350
#
#                Nom en double CODE POL      Energie  Industrie_hors_energie  \
# CODE_COM_2020
# 01001                      1      PRG     0.000000                2.050853
# 01002                      1      PRG     0.000000                0.000000
# 01004                      1      PRG  1235.413217             5737.995199
# 01005                      1      PRG    89.944431              512.394565
# 01006                      1      PRG     0.000000                0.000000
#
#                ...  Unnamed: 13   0  True  CODE_EPCI  \
# CODE_COM_2020  ...
# 01001          ...          NaN NaN   NaN  200069193
# 01002          ...          NaN NaN   NaN  240100883
# 01004          ...          NaN NaN   NaN  240100883
# 01005          ...          NaN NaN   NaN  200042497
# 01006          ...          NaN NaN   NaN  200040350
#
#                Population municipale 2016  Ratio PRG/hab  Unnamed: 4  \
# CODE_COM_2020
# 01001                                 767       6.840264       01001
# 01002                                 243       4.838401       01002
# 01004                               14081       3.950747       01004
# 01005                                1671       3.546388       01005
# 01006                                 110       7.714846       01006
#
#                           Unnamed: 5  Unnamed: 6  \
# CODE_COM_2020
# 01001          ABERGEMENT CLEMENCIAT         NaN
# 01002            ABERGEMENT DE VAREY         NaN
# 01004              AMBERIEU EN BUGEY         NaN
# 01005            AMBERIEUX EN DOMBES         NaN
# 01006                        AMBLEON         NaN
#
#                Source : Insee, Recensement de la population 2016
# CODE_COM_2020
# 01001                                                        NaN
# 01002                                                        NaN
# 01004                                                        NaN
# 01005                                                        NaN
# 01006                                                        NaN
#
# [5 rows x 28 columns]

# %%
COBAN=[
    "33284", #'MIOS',
    "33555", #'MARCHEPRIME',
    "33051",# 'BIGANOS',
    "33019", # 'AUDENGE',
    "33229", # 'LANTON',
    "33005", # 'ANDERNOS-LES-BAINS',
    "33011", # 'ARES',
    "33236", #'LEGE-CAP-FERRET',
    ]

VAL_DE_L_EYRE = [
    "33042", # 'BELIN-BELIET',
    "33029", # 'LE BARP',
    "33260", # 'LUGOS',
    "33436", # 'SAINT-MAGNE',
    "33498", # 'SALLES',
    ]

COBAS = [
    "33009", # 'ARCACHON',
    "33199", # 'GUJAN-MESTRAS',
    "33529", # 'LA TESTE-DE-BUCH',
    "33527", # 'LE TEICH'
    ]
    
SYBARVAL = COBAN + COBAS + VAL_DE_L_EYRE

# %%
df_sybarval = df[df["CODE_COM_2020"].isin(SYBARVAL)]
df_sybarval
# Out:
#                               NOM  NEW_REG CODE_COM_2020        NOM_COM_2020  \
# CODE_COM_2020
# 33005          ANDERNOS LES BAINS       75         33005  ANDERNOS LES BAINS
# 33009                    ARCACHON       75         33009            ARCACHON
# 33011                        ARES       75         33011                ARES
# 33019                     AUDENGE       75         33019             AUDENGE
# 33029                        BARP       75         33029                BARP
# 33042                BELIN BELIET       75         33042        BELIN BELIET
# 33051                     BIGANOS       75         33051             BIGANOS
# 33199               GUJAN MESTRAS       75         33199       GUJAN MESTRAS
# 33229                      LANTON       75         33229              LANTON
# 33236             LEGE CAP FERRET       75         33236     LEGE CAP FERRET
# 33260                       LUGOS       75         33260               LUGOS
# 33284                        MIOS       75         33284                MIOS
# 33436                 SAINT MAGNE       75         33436         SAINT MAGNE
# 33498                      SALLES       75         33498              SALLES
# 33527                       TEICH       75         33527               TEICH
# 33529               TESTE DE BUCH       75         33529       TESTE DE BUCH
# 33555                 MARCHEPRIME       75         33555         MARCHEPRIME
#
#                                                        Nom EPCI       EPCI  \
# CODE_COM_2020
# 33005                              CA du Bassin d'Arcachon Nord  243301504
# 33009          CA Bassin d'Arcachon Sud-Pôle Atlantique (COBAS)  243300563
# 33011                              CA du Bassin d'Arcachon Nord  243301504
# 33019                              CA du Bassin d'Arcachon Nord  243301504
# 33029                                       CC du Val de l'Eyre  243301405
# 33042                                       CC du Val de l'Eyre  243301405
# 33051                              CA du Bassin d'Arcachon Nord  243301504
# 33199          CA Bassin d'Arcachon Sud-Pôle Atlantique (COBAS)  243300563
# 33229                              CA du Bassin d'Arcachon Nord  243301504
# 33236                              CA du Bassin d'Arcachon Nord  243301504
# 33260                                       CC du Val de l'Eyre  243301405
# 33284                              CA du Bassin d'Arcachon Nord  243301504
# 33436                                       CC du Val de l'Eyre  243301405
# 33498                                       CC du Val de l'Eyre  243301405
# 33527          CA Bassin d'Arcachon Sud-Pôle Atlantique (COBAS)  243300563
# 33529          CA Bassin d'Arcachon Sud-Pôle Atlantique (COBAS)  243300563
# 33555                              CA du Bassin d'Arcachon Nord  243301504
#
#                Nom en double CODE POL      Energie  Industrie_hors_energie  \
# CODE_COM_2020
# 33005                      1      PRG   330.678056             1548.938548
# 33009                      1      PRG  1026.424686             4827.471648
# 33011                      1      PRG   111.107827              514.103242
# 33019                      1      PRG    74.071885              351.187501
# 33029                      1      PRG   436.495034            45545.492951
# 33042                      1      PRG   251.315323             1161.401350
# 33051                      1      PRG  1830.633718            50141.533494
# 33199                      1      PRG   880.926341             4123.381944
# 33229                      1      PRG   111.107827              507.570013
# 33236                      1      PRG   375.650272             1865.674055
# 33260                      1      PRG     7.936273              228.173378
# 33284                      1      PRG   695.746630             3385.109437
# 33436                      1      PRG     5.290849               24.592401
# 33498                      6      PRG   722.200874             3613.173097
# 33527                      1      PRG   283.060416             1302.749919
# 33529                      1      PRG  1650.744855             8757.981208
# 33555                      1      PRG   103.171553               61.809683
#
#                ...  Unnamed: 13   0  True  CODE_EPCI  \
# CODE_COM_2020  ...
# 33005          ...          NaN NaN   NaN  243301504
# 33009          ...          NaN NaN   NaN  243300563
# 33011          ...          NaN NaN   NaN  243301504
# 33019          ...          NaN NaN   NaN  243301504
# 33029          ...          NaN NaN   NaN  243301405
# 33042          ...          NaN NaN   NaN  243301405
# 33051          ...          NaN NaN   NaN  243301504
# 33199          ...          NaN NaN   NaN  243300563
# 33229          ...          NaN NaN   NaN  243301504
# 33236          ...          NaN NaN   NaN  243301504
# 33260          ...          NaN NaN   NaN  243301405
# 33284          ...          NaN NaN   NaN  243301504
# 33436          ...          NaN NaN   NaN  243301405
# 33498          ...          NaN NaN   NaN  243301405
# 33527          ...          NaN NaN   NaN  243300563
# 33529          ...          NaN NaN   NaN  243300563
# 33555          ...          NaN NaN   NaN  243301504
#
#                Population municipale 2016  Ratio PRG/hab  Unnamed: 4  \
# CODE_COM_2020
# 33005                               11873       2.606513       33005
# 33009                               11121       4.480645       33009
# 33011                                6202       2.673777       33011
# 33019                                7653       3.231352       33019
# 33029                                5466      12.565915       33029
# 33042                                5375       5.951214       33042
# 33051                               10470       7.681143       33051
# 33199                               20933       1.991854       33199
# 33229                                6725       4.483216       33229
# 33236                                8303       4.335565       33236
# 33260                                 907      12.969509       33260
# 33284                                9513      10.798536       33284
# 33436                                 953       6.096018       33436
# 33498                                6924       7.117090       33498
# 33527                                7730       3.478062       33527
# 33529                               26168       3.989617       33529
# 33555                                4663       2.309157       33555
#
#                        Unnamed: 5  Unnamed: 6  \
# CODE_COM_2020
# 33005          ANDERNOS LES BAINS         NaN
# 33009                    ARCACHON         NaN
# 33011                        ARES         NaN
# 33019                     AUDENGE         NaN
# 33029                        BARP         NaN
# 33042                BELIN BELIET         NaN
# 33051                     BIGANOS         NaN
# 33199               GUJAN MESTRAS         NaN
# 33229                      LANTON         NaN
# 33236             LEGE CAP FERRET         NaN
# 33260                       LUGOS         NaN
# 33284                        MIOS         NaN
# 33436                 SAINT MAGNE         NaN
# 33498                      SALLES         NaN
# 33527                       TEICH         NaN
# 33529               TESTE DE BUCH         NaN
# 33555                 MARCHEPRIME         NaN
#
#                Source : Insee, Recensement de la population 2016
# CODE_COM_2020
# 33005                                                        NaN
# 33009                                                        NaN
# 33011                                                        NaN
# 33019                                                        NaN
# 33029                                                        NaN
# 33042                                                        NaN
# 33051                                                        NaN
# 33199                                                        NaN
# 33229                                                        NaN
# 33236                                                        NaN
# 33260                                                        NaN
# 33284                                                        NaN
# 33436                                                        NaN
# 33498                                                        NaN
# 33527                                                        NaN
# 33529                                                        NaN
# 33555                                                        NaN
#
# [17 rows x 28 columns]

# %%
[col for col in df_sybarval.columns]
# Out:
# ['NOM',
#  'NEW_REG',
#  'CODE_COM_2020',
#  'NOM_COM_2020',
#  'Nom EPCI',
#  'EPCI',
#  'Nom en double',
#  'CODE POL',
#  'Energie',
#  'Industrie_hors_energie',
#  'Residentiel',
#  'Tertiaire',
#  'Dechets',
#  'Routier',
#  'Autres_Transports',
#  'Autres_Transports_international',
#  'Agriculture',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  0,
#  True,
#  'CODE_EPCI',
#  'Population municipale 2016',
#  'Ratio PRG/hab',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Source : Insee, Recensement de la population 2016']

# %%
all_cols =  [
    'Energie',
    'Industrie_hors_energie',
    'Residentiel',
    'Tertiaire',
    'Dechets',
    'Routier',
    'Autres_Transports',
    'Autres_Transports_international',
    'Agriculture',
]

transports = [
    'Routier',
    'Autres_Transports',
    'Autres_Transports_international',
]

# %%
emissions_transports = df_sybarval[transports].agg("sum").sum()
print(f"{emissions_transports=}")
# Out:
# emissions_transports=372258.70313036395

# %%
emissions_toutes  = df_sybarval[all_cols].agg("sum").sum()
print(f"{emissions_toutes=}")
# Out:
# emissions_toutes=722657.9798793918

# %%
transport_percent = emissions_transports/emissions_toutes
print(f"{transport_percent=}")
# Out:
# transport_percent=0.515124323670365

# %%
df_sybarval[["NOM"]+transports+all_cols]
# Out:
#                               NOM       Routier  Autres_Transports  \
# CODE_COM_2020
# 33005          ANDERNOS LES BAINS  13422.819879           0.000000
# 33009                    ARCACHON  19399.107866          46.069608
# 33011                        ARES   8010.545636           0.000000
# 33019                     AUDENGE   7565.840693           3.834899
# 33029                        BARP  10562.040260           0.000000
# 33042                BELIN BELIET  25389.004399           0.000000
# 33051                     BIGANOS  16493.165105          95.310616
# 33199               GUJAN MESTRAS  13760.896523          56.080720
# 33229                      LANTON  19728.950969           0.000000
# 33236             LEGE CAP FERRET  20891.297463         628.718008
# 33260                       LUGOS   9844.517161          39.394235
# 33284                        MIOS  89031.385617          29.369365
# 33436                 SAINT MAGNE   4796.145000           0.000000
# 33498                      SALLES  36958.941354          58.180823
# 33527                       TEICH  16880.141194         114.763844
# 33529               TESTE DE BUCH  50331.125514        2340.665087
# 33555                 MARCHEPRIME   5712.526133          67.865158
#
#                Autres_Transports_international      Energie  \
# CODE_COM_2020
# 33005                                      0.0   330.678056
# 33009                                      0.0  1026.424686
# 33011                                      0.0   111.107827
# 33019                                      0.0    74.071885
# 33029                                      0.0   436.495034
# 33042                                      0.0   251.315323
# 33051                                      0.0  1830.633718
# 33199                                      0.0   880.926341
# 33229                                      0.0   111.107827
# 33236                                      0.0   375.650272
# 33260                                      0.0     7.936273
# 33284                                      0.0   695.746630
# 33436                                      0.0     5.290849
# 33498                                      0.0   722.200874
# 33527                                      0.0   283.060416
# 33529                                      0.0  1650.744855
# 33555                                      0.0   103.171553
#
#                Industrie_hors_energie   Residentiel     Tertiaire  \
# CODE_COM_2020
# 33005                     1548.938548  11894.155077   3422.486306
# 33009                     4827.471648  18551.048829   5665.395046
# 33011                      514.103242   5010.113978   2651.079593
# 33019                      351.187501   5253.986349   1844.182087
# 33029                    45545.492951   3065.906898   7268.798776
# 33042                     1161.401350   3153.112894   1464.720537
# 33051                    50141.533494   7105.058024   4395.549344
# 33199                     4123.381944  15841.977937   6378.501226
# 33229                      507.570013   5483.945279   2150.458691
# 33236                     1865.674055   9254.939286   2822.197268
# 33260                      228.173378    348.174469    238.143768
# 33284                     3385.109437   5808.995953   3203.967369
# 33436                       24.592401    344.675125    239.441667
# 33498                     3613.173097   4853.382958   1958.178678
# 33527                     1302.749919   5154.088343   2647.060222
# 33529                     8757.981208  26265.217710  14680.000823
# 33555                       61.809683   2806.664851   1640.743121
#
#                    Dechets       Routier  Autres_Transports  \
# CODE_COM_2020
# 33005           168.219950  13422.819879           0.000000
# 33009           157.565405  19399.107866          46.069608
# 33011            87.871652   8010.545636           0.000000
# 33019          8191.256237   7565.840693           3.834899
# 33029            77.443801  10562.040260           0.000000
# 33042            76.154487  25389.004399           0.000000
# 33051           157.888891  16493.165105          95.310616
# 33199           296.584537  13760.896523          56.080720
# 33229            95.281661  19728.950969           0.000000
# 33236           117.639202  20891.297463         628.718008
# 33260            28.870514   9844.517161          39.394235
# 33284           134.782817  89031.385617          29.369365
# 33436            30.334730   4796.145000           0.000000
# 33498            98.101148  36958.941354          58.180823
# 33527           109.520779  16880.141194         114.763844
# 33529           374.550836  50331.125514        2340.665087
# 33555            66.715718   5712.526133          67.865158
#
#                Autres_Transports_international  Agriculture
# CODE_COM_2020
# 33005                                      0.0   159.831327
# 33009                                      0.0   156.170042
# 33011                                      0.0   197.944075
# 33019                                      0.0  1445.180300
# 33029                                      0.0  1729.111915
# 33042                                      0.0   492.067797
# 33051                                      0.0   202.426732
# 33199                                      0.0   357.132460
# 33229                                      0.0  2072.312379
# 33236                                      0.0    42.077417
# 33260                                      0.0  1028.134497
# 33284                                      0.0   437.112636
# 33436                                      0.0   369.025686
# 33498                                      0.0  1016.573764
# 33527                                      0.0   394.037942
# 33529                                      0.0     0.000000
# 33555                                      0.0   308.100650
