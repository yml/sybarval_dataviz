# %% [markdown]
# # Sybarval emmision carto

# %%
import geopandas as gpd

communes = gpd.read_file("_data_cache/communes-nouvelle-aquitaine.geojson")
communes[communes["code"]=="33005"]
# Out:
#        code                 nom  \
# 1708  33005  Andernos-les-Bains
#
#                                                geometry
# 1708  POLYGON ((-1.07819 44.72219, -1.08665 44.72653...

# %%
COBAN=[
    "33284", #'MIOS',
    "33555", #'MARCHEPRIME',
    "33051",# 'BIGANOS',
    "33019", # 'AUDENGE',
    "33229", # 'LANTON',
    "33005", # 'ANDERNOS-LES-BAINS',
    "33011", # 'ARES',
    "33236", #'LEGE-CAP-FERRET',
    ]

VAL_DE_L_EYRE = [
    "33042", # 'BELIN-BELIET',
    "33029", # 'LE BARP',
    "33260", # 'LUGOS',
    "33436", # 'SAINT-MAGNE',
    "33498", # 'SALLES',
    ]

COBAS = [
    "33009", # 'ARCACHON',
    "33199", # 'GUJAN-MESTRAS',
    "33529", # 'LA TESTE-DE-BUCH',
    "33527", # 'LE TEICH'
    ]
    
SYBARVAL = COBAN + COBAS + VAL_DE_L_EYRE

# %%
geo_sybarval = communes[communes["code"].isin(SYBARVAL)]
geo_sybarval
# Out:
#        code                 nom  \
# 88    33009            Arcachon
# 239   33527               Teich
# 414   33555         Marcheprime
# 740   33236     Lège-Cap-Ferret
# 1468  33529       Teste-de-Buch
# 1708  33005  Andernos-les-Bains
# 1762  33199       Gujan-Mestras
# 2014  33498              Salles
# 2076  33029                Barp
# 2229  33436         Saint-Magne
# 3345  33260               Lugos
# 3393  33019             Audenge
# 3498  33042        Belin-Béliet
# 3746  33284                Mios
# 4146  33051             Biganos
# 4271  33229              Lanton
# 4313  33011                Arès
#
#                                                geometry
# 88    POLYGON ((-1.20435 44.63870, -1.19154 44.66073...
# 239   POLYGON ((-1.04405 44.64788, -1.00468 44.64819...
# 414   POLYGON ((-0.90676 44.69958, -0.83904 44.72920...
# 740   POLYGON ((-1.16193 44.77490, -1.16857 44.77177...
# 1468  POLYGON ((-1.10699 44.50264, -1.19981 44.47959...
# 1708  POLYGON ((-1.07819 44.72219, -1.08665 44.72653...
# 1762  POLYGON ((-1.10699 44.50264, -1.10433 44.54225...
# 2014  POLYGON ((-0.84212 44.51796, -0.85315 44.52503...
# 2076  POLYGON ((-0.77144 44.69303, -0.72996 44.67257...
# 2229  POLYGON ((-0.60901 44.60364, -0.61593 44.58199...
# 3345  POLYGON ((-0.84212 44.51796, -0.81957 44.50814...
# 3393  POLYGON ((-1.01786 44.66798, -1.02331 44.67503...
# 3498  POLYGON ((-0.78028 44.42811, -0.79306 44.42869...
# 3746  POLYGON ((-0.97915 44.62191, -0.94623 44.63861...
# 4146  POLYGON ((-1.01786 44.66798, -0.99694 44.66868...
# 4271  POLYGON ((-1.04093 44.78278, -1.02620 44.79712...
# 4313  POLYGON ((-1.04093 44.78278, -1.08323 44.77415...

# %%
ax = geo_sybarval.plot()
ax.set_axis_off()

# %%
import numpy as np

URL = "https://data.ademe.fr/data-fair/api/v1/datasets/igt-pouvoir-de-rechauffement-global/full"
FILE  = "_data_cache/igt_ademe_2016.csv"

# df = pd.read_csv(URL)
igt_df = pd.read_csv(FILE)

# %%
igt_sybarval = igt_df[igt_df["INSEE commune"].isin(SYBARVAL)]
igt_sybarval
# Out:
#       INSEE commune             Commune  Agriculture  Autres transports  \
# 12672         33005  ANDERNOS-LES-BAINS   246.335648                NaN
# 12676         33009            ARCACHON   208.823953          42.189423
# 12678         33011                ARES   236.385326                NaN
# 12686         33019             AUDENGE  3117.438503           1.489062
# 12696         33029             LE BARP  1941.054472                NaN
# 12708         33042        BELIN-BELIET  1643.429836                NaN
# 12717         33051             BIGANOS   347.953450         227.687953
# 12864         33199       GUJAN-MESTRAS   691.567977         133.971481
# 12893         33229              LANTON  2632.416240                NaN
# 12900         33236     LEGE-CAP-FERRET   318.430528         244.126403
# 12924         33260               LUGOS  2781.820761          94.109062
# 12947         33284                MIOS  1162.077806          70.160607
# 13092         33436         SAINT-MAGNE   814.405837                NaN
# 13150         33498              SALLES  1390.665182         138.988427
# 13179         33527            LE TEICH   891.793230         274.159856
# 13181         33529    LA TESTE-DE-BUCH   382.744272         980.212901
# 13207         33555         MARCHEPRIME   837.462523         162.123376
#
#        Autres transports international  CO2 biomasse hors-total      Déchets  \
# 12672                              NaN              8248.644104    95.620427
# 12676                              NaN             10071.084650    86.541649
# 12678                              NaN              3982.604467    47.963041
# 12686                              NaN              4691.340173  7349.622715
# 12696                              NaN             17259.297730    42.279511
# 12708                              NaN              5397.258536    39.900360
# 12717                              NaN             11574.755710    82.196393
# 12864                              NaN             14623.139390   167.647598
# 12893                              NaN              5185.745722    54.266141
# 12900                              NaN              6796.268309    66.963212
# 12924                              NaN              1353.787747   113.993573
# 12947                              NaN             12424.980430    68.202354
# 13092                              NaN               906.342215   133.830042
# 13150                              NaN              7977.763925    53.811789
# 13179                              NaN              5663.509635    59.107054
# 13181                              NaN             21269.958040   211.372774
# 13207                              NaN              3273.302659    37.570773
#
#            Energie  Industrie hors-énergie   Résidentiel       Routier  \
# 12672   277.837813              815.523175  15031.423140  13008.128700
# 12676   979.496020             2875.064754  24975.550790  18275.984070
# 12678    61.218501              179.691547   5852.954789   7863.067248
# 12686    68.282174              200.425187   5935.578784   7365.755394
# 12696   240.164890            20903.972260   3388.822983  10806.034260
# 12708   235.455774              691.121335   3601.604246  25708.844490
# 12717  1791.818441            44041.312020   8685.704595  16019.853210
# 12864   751.103919             2204.677059  19398.463120  13474.640230
# 12893    49.445713              145.135480   6632.953129  19589.844990
# 12900   282.546929              829.345602  10556.882640  20100.055920
# 12924    14.127346               41.467280    283.647296  10008.962700
# 12947   562.739300             1651.779991   6341.087405  92390.879130
# 13092     4.709115               13.822427    318.687736   4834.470450
# 13150   543.902838             1596.490284   5496.962724  36699.011920
# 13179   162.464484              476.873721   6339.602041  17510.623880
# 13181  1146.669620             3365.760902  32386.952230  48076.480810
# 13207   103.600541              304.093387   3190.876139   5619.100560
#
#           Tertiaire        lat       lon
# 12672   6399.686262  44.742448 -1.090931
# 12676   5689.672379  44.658380 -1.169450
# 12678   2778.372903  44.764183 -1.136804
# 12686   4858.354272  44.683088 -1.013330
# 12696   7045.431811  44.606091 -0.768121
# 12708   2896.220268  44.497153 -0.791073
# 12717   7768.795140  44.643766 -0.978962
# 12864  11400.296050  44.635116 -1.067986
# 12893   4566.840084  44.702988 -1.036237
# 12900   5029.653920  44.792671 -1.146498
# 12924    412.496976  44.482140 -0.885743
# 12947   4504.724839  44.604704 -0.937090
# 13092    484.277192  44.526873 -0.658269
# 13150   4444.191832  44.551181 -0.870330
# 13179   4568.661353  44.633088 -1.024917
# 13181  25625.831680  44.632214 -1.146050
# 13207   2176.376156  44.691391 -0.855964

# %%
joined_sybarval = geo_sybarval.set_index("code").join(igt_sybarval.set_index("INSEE commune"))

# %%
ax = joined_sybarval.plot('Routier', legend=True)
ax.set_axis_off()
ax.set_title("GES  Emmission pour le transport routier en tCO2/an")
# Out:
# Text(0.5, 1.0, 'GES  Emmission pour le transport routier en tCO2/an')

# %%
all_emmissions = [
    "Autres transports",
    "Routier",
    "Autres transports international",
    "Agriculture",
    "CO2 biomasse hors-total",
    "Déchets",
    "Energie",
    "Industrie hors-énergie",
    "Résidentiel",
    "Tertiaire",
]

# %%
ax = joined_sybarval.plot(joined_sybarval[all_emmissions].sum(axis=1), legend=True)
ax.set_axis_off()
ax.set_title("GES  Emmission en tCO2/an")
# Out:
# Text(0.5, 1.0, 'GES  Emmission en tCO2/an')
